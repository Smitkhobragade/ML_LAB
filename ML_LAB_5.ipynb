# %% [markdown]
# ## Smit Khobragade
# ### Sec: A
# ### Roll no.: 64

# %% [markdown]
# ## Practical 5
# use ID3 Algorithm to find the root node of the decision tree
# 1. fins entropy of overall sample
# 2. find information gain of each attribute

# %%
import numpy as np
import pandas as pd

# %%
eps = np.finfo(float).eps
from numpy import log2 as log

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/PlayTennis.csv')
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
print(df.columns)
# Out:
# Index(['outlook', 'temp', 'humidity', 'windy', 'play'], dtype='object')

# %%
df.describe()
# Out:
#        outlook  temp humidity  windy play
# count       14    14       14     14   14
# unique       3     3        2      2    2
# top      sunny  mild     high  False  yes
# freq         5     6        7      8    9

# %%
def find_entropy(df):
    #target column
    target = df.keys()[-1]
    entropy = 0
    values = df[target].unique()
    #calc entropy
    for value in values:
        fraction = df[target].value_counts()[value]/len(df[target])
        entropy += -fraction*np.log2(fraction)
    return entropy

entropy = find_entropy(df)
entropy
# Out:
# 0.9402859586706311

# %%
def average_information(df,attribute):
  target = df.keys()[-1]   #target column
  target_variables = df[target].unique()  #This gives all 'Yes' and 'No'
  variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
  entropy2 = 0
  for variable in variables:
      entropy = 0
      for target_variable in target_variables:
          num = len(df[attribute][df[attribute]==variable][df[target] ==target_variable])
          den = len(df[attribute][df[attribute]==variable])
          fraction = num/(den+eps)
          entropy += -fraction*log(fraction+eps)
      fraction2 = den/len(df)

      entropy2 += -fraction2*entropy
  return abs(entropy2)

# %%
IG = []
I = []
for key in df.keys()[:-1]:
  x = average_information(df,key)
  I.append(x)
  IG.append([key, entropy-x])

IG
# Out:
# [['outlook', 0.24674981977443977],
#  ['temp', 0.029222565658955535],
#  ['humidity', 0.15183550136234225],
#  ['windy', 0.048127030408270155]]

# %%
entropy
# Out:
# 0.9402859586706311
